# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('car_1.csv')
df
# Out:
#        userid  gender  age  income  purchase
# 0   123456780    male   19   19000         0
# 1   123456781    male   25   20000         0
# 2   123456782  female   26   43000         1
# 3   123456783  female   27   57000         0
# 4   123456784    male   19   76000         1
# 5   123456785    male   27   58000         1
# 6   123456786  female   27   84000         0
# 7   123456787  female   32  190000         1
# 8   123456788    male   25   33000         0
# 9   123456789  female   35   65000         1
# 10  123456790  female   26   80000         0
# 11  123456791  female   26   25000         0
# 12  123456792    male   20   26000         1

# %%
X = df.iloc[:,[2,3]].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
print(X_train)
# Out:
# [[    26  43000]
#  [    25  33000]
#  [    25  20000]
#  [    32 190000]
#  [    35  65000]
#  [    27  57000]
#  [    19  19000]
#  [    27  58000]
#  [    20  26000]]

# %%
print(X_test)
# Out:
# [[   27 84000]
#  [   26 25000]
#  [   19 76000]
#  [   26 80000]]

# %%
print(y_train)
# Out:
# [1 0 0 1 1 0 0 1 1]

# %%
print(y_test)
# Out:
# [0 0 1 0]

# %%
from sklearn.preprocessing import StandardScaler
model = StandardScaler()
X_train = model.fit_transform(X_train)
X_test = model.transform(X_test)

# %%
print(X_train)
print()
print(X_test)
# Out:
# [[-0.04649906 -0.27679123]
#  [-0.25574481 -0.47768809]
#  [-0.25574481 -0.73885401]
#  [ 1.20897544  2.67639263]
#  [ 1.83671269  0.16518186]
#  [ 0.16274669  0.00446437]
#  [-1.5112193  -0.7589437 ]
#  [ 0.16274669  0.02455406]
#  [-1.30197355 -0.61831589]]
#
# [[ 0.16274669  0.5468859 ]
#  [-0.04649906 -0.63840558]
#  [-1.5112193   0.38616841]
#  [-0.04649906  0.46652716]]

# %%
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()
regressor.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([1, 0, 0, 1])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[1 2]
#  [1 0]]
# 0.25

# %%
regressor.predict(model.transform([[3,700]]))
# Out:
# array([0])
