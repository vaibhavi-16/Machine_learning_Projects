# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('marks.csv')
df
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
plt.scatter(df.SAT,df.GPA)
plt.show()

# %%
x = df.iloc[:,[0]].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
print(y_test)
# Out:
# [3.28 3.37 3.39 3.41 3.2  3.44 2.54 3.47 3.28 3.01 3.58 3.08 3.52 3.65
#  3.17 3.28 3.62 3.6  3.41 3.61 3.81]

# %%
from sklearn.preprocessing import StandardScaler
model = StandardScaler()
x_train = model.fit_transform(x_train)
x_test = model.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([3.19088106, 3.34941676, 3.08023635, 3.24537771, 3.01583122,
#        3.37253655, 3.17601834, 3.12647593, 3.22060651, 3.22886357,
#        3.45841006, 3.09675049, 3.32464556, 3.60538587, 3.16776127,
#        3.27675457, 3.5971288 , 3.4633643 , 3.33620546, 3.60703728,
#        3.65492828])

# %%
regressor.predict(model.transform([[2100]]))
# Out:
# array([3.73749895])

# %%
#how to make a graph of best fit line of this model for train and test data set
plt.scatter(x_train,y_train)
plt.plot(x_train,regressor.predict(x_train))

# %%
plt.scatter(x_test,y_test)
plt.plot(x_train,regressor.predict(x_train))
